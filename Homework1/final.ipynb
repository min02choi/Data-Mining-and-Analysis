# %% [markdown]
# > kaggle: 0.88082

# %% [markdown]
# # 목차
# 1. 데이터 불러오기
# 2. 데이터 탐색과정(Feature Engineering)
#     * 전반적인 데이터 확인
#     * feature 처리(categorical, numerical)
# 3. feature 선택
# 4. model 선택
#     * Decision Tree
#     * k-Nearest Neighbors
#     * Naive Bayes
#     * Logistic Regression
#     * Artificial Neural Networks
# 5. 성능 평가 및 제출

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# train, test 데이터 가져오기
# booking_status는 0, 1로 바꾸어 가져오기
train = pd.read_csv('./train.csv')
train["booking_status"] = train["booking_status"].replace({'Canceled':1, 'Not_Canceled':0})

test = pd.read_csv('./test.csv')
train.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN29581             2               0                     1
# 1   INN06326             2               0                     1
# 2   INN33900             2               0                     1
# 3   INN00721             2               0                     2
# 4   INN22121             2               1                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  3       Meal Plan 1                           0
# 1                  3       Meal Plan 1                           0
# 2                  4       Meal Plan 1                           0
# 3                  0       Meal Plan 1                           0
# 4                  4       Meal Plan 1                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        200          2018              8            29
# 1        Room_Type 1         79          2018              3            24
# 2        Room_Type 4         78          2018              4             6
# 3        Room_Type 1         61          2017             10             4
# 4        Room_Type 1        201          2018             11             1
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0              Online               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3             Offline               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               90.95
# 1                                     0               90.95
# 2                                     0               99.45
# 3                                     0               91.00
# 4                                     0               82.28
#
#    no_of_special_requests  booking_status
# 0                       0               1
# 1                       1               1
# 2                       1               0
# 3                       0               0
# 4                       3               0

# %% [markdown]
# ## 2. 데이터 탐색 과정(Feature Engineering)

# %% [markdown]
# ### 2-1) 전반적인 데이터 확인
# * 데이터의 대략적인 값 확인
# * 결측치 확인
# * 데이터 분포 확인

# %%
train.shape, test.shape
# Out:
# ((25392, 19), (10883, 18))

# %%
# train data 확인
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25392 entries, 0 to 25391
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            25392 non-null  object
#  1   no_of_adults                          25392 non-null  int64
#  2   no_of_children                        25392 non-null  int64
#  3   no_of_weekend_nights                  25392 non-null  int64
#  4   no_of_week_nights                     25392 non-null  int64
#  5   type_of_meal_plan                     25392 non-null  object
#  6   required_car_parking_space            25392 non-null  int64
#  7   room_type_reserved                    25392 non-null  object
#  8   lead_time                             25392 non-null  int64
#  9   arrival_year                          25392 non-null  int64
#  10  arrival_month                         25392 non-null  int64
#  11  arrival_date                          25392 non-null  int64
#  12  market_segment_type                   25392 non-null  object
#  13  repeated_guest                        25392 non-null  int64
#  14  no_of_previous_cancellations          25392 non-null  int64
#  15  no_of_previous_bookings_not_canceled  25392 non-null  int64
#  16  avg_price_per_room                    25392 non-null  float64
#  17  no_of_special_requests                25392 non-null  int64
#  18  booking_status                        25392 non-null  int64
# dtypes: float64(1), int64(14), object(4)
# memory usage: 3.7+ MB

# %%
# 비어있는 값 확인
train.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# dtype: int64

# %% [markdown]
# 비어있는 값이 없음, 고로 그냥 진행해도 됨

# %%
# Booking_ID는 상관 없으니 삭제
train.drop(['Booking_ID'], axis=1, inplace=True)
test.drop(['Booking_ID'], axis=1, inplace=True)

# %%
# 데이터 분포 확인: 단순 해당 feature에 대해서
fig, axes = plt.subplots(6, 3, figsize=(15, 12))
for idx, val in enumerate(list(set(train.columns))):
    sns.histplot(data=train, x=val, ax=axes[idx // 3, idx % 3], stat='count')
    plt.xlabel = val
plt.tight_layout()
plt.show()

# %% [markdown]
# features중 뚜렷한 특징을 보이는 features는 lead_time, avg_price_per_room 정도이다.

# %%
# 위와 동일한 표에서 'booking_status'과의 관계를 추가로 나타냄
fig, axes = plt.subplots(6, 3, figsize=(15,12))
for idx, val in enumerate(list(set(train.columns))):
    sns.histplot(data=train, x=val, ax=axes[idx // 3, idx % 3],stat='count', hue='booking_status', kde=True)
    plt.xlabel = val
fig.tight_layout()
plt.show()

# %% [markdown]
# features중 booking_status와 연관성을 보이는 것은 lead_time, market_segment_type, room_type_reserved, avg_price_per_room, required_car_parking_space, type_of_meal_plan, no_of_week_nights, no_of_special_requests 정도이다.

# %%
# heatmap으로 각 feature간의 상관관계 확인
sns.set(rc={'figure.figsize':(15, 13)}) 
correlation_matrix = train.corr()
sns.heatmap(data=correlation_matrix, annot=True) 
plt.show()

# %%
# 우리의 target값인 booking_status을 기준으로 상관관계 정렬
correlation = train.corr()['booking_status'].abs().sort_values(ascending = False)
correlation
# Out:
# booking_status                          1.000000
# lead_time                               0.432341
# no_of_special_requests                  0.254901
# arrival_year                            0.175495
# avg_price_per_room                      0.145585
# repeated_guest                          0.106916
# no_of_adults                            0.091378
# required_car_parking_space              0.090402
# no_of_week_nights                       0.090325
# no_of_previous_bookings_not_canceled    0.058706
# no_of_weekend_nights                    0.057094
# no_of_children                          0.031683
# no_of_previous_cancellations            0.030817
# arrival_month                           0.014238
# arrival_date                            0.011965
# Name: booking_status, dtype: float64

# %% [markdown]
# lead_time이 0.432341을 기록하여 booking_status을 결정하는데 가장 중요한 영향을 미친다고 판단할 수 있다. no_of_special_requests, arrival_year 등의 feature가 그 뒤를 잇는다.

# %% [markdown]
# ### 2-2) feature 처리(1) - categorical
# dataset를 확인해보면 type_of_meal_plan, room_type_reserved, market_segment_type은 object type를 가진다. 이러한 값을 정수형(int)로 바꾸어준다.

# %%
# categorical features 탐색
cat_cols = [col for col in train.columns if train[col].dtype == object]
cat_cols
# Out:
# ['type_of_meal_plan', 'room_type_reserved', 'market_segment_type']

# %% [markdown]
# #### 1) type_of_meal_plan
# 항목의 수량이 많은 순서대로 0부터 할당하되, 'Meal Plan 3'은 수가 너무 적은 관계로 데이터의 비중이 가장 큰 'Meal Plan 1'에 사상

# %%
train['type_of_meal_plan'].value_counts()
# Out:
# Meal Plan 1     19492
# Not Selected     3560
# Meal Plan 2      2338
# Meal Plan 3         2
# Name: type_of_meal_plan, dtype: int64

# %%
meal_mapping = {
    'Meal Plan 1': 0, 'Meal Plan 2': 1, 'Not Selected': 2, 'Meal Plan 3': 0
}

for data in [train, test]:
    data['type_of_meal_plan'] = data['type_of_meal_plan'].map(meal_mapping)

# %% [markdown]
# #### 2. room_type_reserved

# %%
train['room_type_reserved'].value_counts()
# Out:
# Room_Type 1    19684
# Room_Type 4     4242
# Room_Type 6      667
# Room_Type 2      498
# Room_Type 5      186
# Room_Type 7      111
# Room_Type 3        4
# Name: room_type_reserved, dtype: int64

# %%
roomType_mapping = {
    'Room_Type 1': 0, 'Room_Type 4': 1, 'Room_Type 6': 2, 'Room_Type 2': 3, 'Room_Type 5': 4, 'Room_Type 7': 5, 'Room_Type 3': 6
}

for data in [train, test]:
    data['room_type_reserved'] = data['room_type_reserved'].map(roomType_mapping)

# %% [markdown]
# #### 3. market_segment_type

# %%
train['market_segment_type'].value_counts()
# Out:
# Online           16210
# Offline           7398
# Corporate         1427
# Complementary      272
# Aviation            85
# Name: market_segment_type, dtype: int64

# %%
marketType_mapping = {
    'Online': 0, 'Offline': 1, 'Corporate': 2, 'Complementary': 3, 'Aviation': 4
}

for data in [train, test]:
    data['market_segment_type'] = data['market_segment_type'].map(marketType_mapping)

# %%
train[cat_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25392 entries, 0 to 25391
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   type_of_meal_plan    25392 non-null  int64
#  1   room_type_reserved   25392 non-null  int64
#  2   market_segment_type  25392 non-null  int64
# dtypes: int64(3)
# memory usage: 595.2 KB

# %%
# 변경사항 확인
train[cat_cols].head()
# Out:
#    type_of_meal_plan  room_type_reserved  market_segment_type
# 0                  0                   0                    0
# 1                  0                   0                    0
# 2                  0                   1                    0
# 3                  0                   0                    1
# 4                  0                   0                    0

# %% [markdown]
# ### 2-2) feature 처리(2) - numerical
# * 이상치 제거
# * feature 생성
# * 정규화

# %%
# train data 중 cat_cols에 들어가 있지 않은 column: numerical
num_cols = [col for col in train.columns if col not in cat_cols]

# booking_status는 target이므로 제외
num_cols.remove('booking_status')

num_cols
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests']

# %%
# date와 관련된 column은 따로 빼둠
date = ['arrival_year', 'arrival_month', 'arrival_date']

for col in date:
    num_cols.remove(col)

# %% [markdown]
# #### 1. 이상치 제거

# %%
# numerical 데이터 확인
train[num_cols].describe().T.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a9e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a9e0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_0a9e0_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_0a9e0_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_0a9e0_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_0a9e0_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_0a9e0_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_0a9e0_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_0a9e0_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a9e0_level0_row0" class="row_heading level0 row0" >no_of_adults</th>
#       <td id="T_0a9e0_row0_col0" class="data row0 col0" >25392.000000</td>
#       <td id="T_0a9e0_row0_col1" class="data row0 col1" >1.845069</td>
#       <td id="T_0a9e0_row0_col2" class="data row0 col2" >0.519044</td>
#       <td id="T_0a9e0_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_0a9e0_row0_col4" class="data row0 col4" >2.000000</td>
#       <td id="T_0a9e0_row0_col5" class="data row0 col5" >2.000000</td>
#       <td id="T_0a9e0_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_0a9e0_row0_col7" class="data row0 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row1" class="row_heading level0 row1" >no_of_children</th>
#       <td id="T_0a9e0_row1_col0" class="data row1 col0" >25392.000000</td>
#       <td id="T_0a9e0_row1_col1" class="data row1 col1" >0.105151</td>
#       <td id="T_0a9e0_row1_col2" class="data row1 col2" >0.401900</td>
#       <td id="T_0a9e0_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_0a9e0_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_0a9e0_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_0a9e0_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_0a9e0_row1_col7" class="data row1 col7" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row2" class="row_heading level0 row2" >no_of_weekend_nights</th>
#       <td id="T_0a9e0_row2_col0" class="data row2 col0" >25392.000000</td>
#       <td id="T_0a9e0_row2_col1" class="data row2 col1" >0.810137</td>
#       <td id="T_0a9e0_row2_col2" class="data row2 col2" >0.867761</td>
#       <td id="T_0a9e0_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_0a9e0_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_0a9e0_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_0a9e0_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_0a9e0_row2_col7" class="data row2 col7" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row3" class="row_heading level0 row3" >no_of_week_nights</th>
#       <td id="T_0a9e0_row3_col0" class="data row3 col0" >25392.000000</td>
#       <td id="T_0a9e0_row3_col1" class="data row3 col1" >2.201323</td>
#       <td id="T_0a9e0_row3_col2" class="data row3 col2" >1.396599</td>
#       <td id="T_0a9e0_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_0a9e0_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_0a9e0_row3_col5" class="data row3 col5" >2.000000</td>
#       <td id="T_0a9e0_row3_col6" class="data row3 col6" >3.000000</td>
#       <td id="T_0a9e0_row3_col7" class="data row3 col7" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row4" class="row_heading level0 row4" >required_car_parking_space</th>
#       <td id="T_0a9e0_row4_col0" class="data row4 col0" >25392.000000</td>
#       <td id="T_0a9e0_row4_col1" class="data row4 col1" >0.031348</td>
#       <td id="T_0a9e0_row4_col2" class="data row4 col2" >0.174261</td>
#       <td id="T_0a9e0_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_0a9e0_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_0a9e0_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_0a9e0_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_0a9e0_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row5" class="row_heading level0 row5" >lead_time</th>
#       <td id="T_0a9e0_row5_col0" class="data row5 col0" >25392.000000</td>
#       <td id="T_0a9e0_row5_col1" class="data row5 col1" >85.411508</td>
#       <td id="T_0a9e0_row5_col2" class="data row5 col2" >85.745937</td>
#       <td id="T_0a9e0_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_0a9e0_row5_col4" class="data row5 col4" >17.000000</td>
#       <td id="T_0a9e0_row5_col5" class="data row5 col5" >58.000000</td>
#       <td id="T_0a9e0_row5_col6" class="data row5 col6" >127.000000</td>
#       <td id="T_0a9e0_row5_col7" class="data row5 col7" >443.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row6" class="row_heading level0 row6" >repeated_guest</th>
#       <td id="T_0a9e0_row6_col0" class="data row6 col0" >25392.000000</td>
#       <td id="T_0a9e0_row6_col1" class="data row6 col1" >0.025165</td>
#       <td id="T_0a9e0_row6_col2" class="data row6 col2" >0.156630</td>
#       <td id="T_0a9e0_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_0a9e0_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_0a9e0_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_0a9e0_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_0a9e0_row6_col7" class="data row6 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row7" class="row_heading level0 row7" >no_of_previous_cancellations</th>
#       <td id="T_0a9e0_row7_col0" class="data row7 col0" >25392.000000</td>
#       <td id="T_0a9e0_row7_col1" class="data row7 col1" >0.023905</td>
#       <td id="T_0a9e0_row7_col2" class="data row7 col2" >0.378652</td>
#       <td id="T_0a9e0_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_0a9e0_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_0a9e0_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_0a9e0_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_0a9e0_row7_col7" class="data row7 col7" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row8" class="row_heading level0 row8" >no_of_previous_bookings_not_canceled</th>
#       <td id="T_0a9e0_row8_col0" class="data row8 col0" >25392.000000</td>
#       <td id="T_0a9e0_row8_col1" class="data row8 col1" >0.156191</td>
#       <td id="T_0a9e0_row8_col2" class="data row8 col2" >1.818933</td>
#       <td id="T_0a9e0_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_0a9e0_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_0a9e0_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_0a9e0_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_0a9e0_row8_col7" class="data row8 col7" >58.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row9" class="row_heading level0 row9" >avg_price_per_room</th>
#       <td id="T_0a9e0_row9_col0" class="data row9 col0" >25392.000000</td>
#       <td id="T_0a9e0_row9_col1" class="data row9 col1" >103.485770</td>
#       <td id="T_0a9e0_row9_col2" class="data row9 col2" >35.067053</td>
#       <td id="T_0a9e0_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_0a9e0_row9_col4" class="data row9 col4" >80.750000</td>
#       <td id="T_0a9e0_row9_col5" class="data row9 col5" >99.865000</td>
#       <td id="T_0a9e0_row9_col6" class="data row9 col6" >120.150000</td>
#       <td id="T_0a9e0_row9_col7" class="data row9 col7" >375.500000</td>
#     </tr>
#     <tr>
#       <th id="T_0a9e0_level0_row10" class="row_heading level0 row10" >no_of_special_requests</th>
#       <td id="T_0a9e0_row10_col0" class="data row10 col0" >25392.000000</td>
#       <td id="T_0a9e0_row10_col1" class="data row10 col1" >0.618305</td>
#       <td id="T_0a9e0_row10_col2" class="data row10 col2" >0.786555</td>
#       <td id="T_0a9e0_row10_col3" clas

# %% [markdown]
# lead_time, avg_price_per_room에서 이상치가 감지됨

# %%
# boxplot를 그림으로서 해당 feature의 분포 및 이상치 확인
outliers_col = ['avg_price_per_room', 'lead_time']

fig, axis = plt.subplots(1, 2, figsize=(18,4))
ax = axis.flatten()

for i, fea in enumerate(outliers_col): 
    sns.boxplot(data=train, x=train[fea], ax=axis[i])

# %% [markdown]
# * avg_price_per_room: 350부터 outlier로 판정
# * lead_time: 400부터 outlier로 판정

# %% [markdown]
# 두 feature에서 avg_price_per_room, lead_time은 각각 350, 400정도부터 이상치로 판단이 되지만 이상치를 제거하지 않고 학습한 모델이 이상치를 제거하고 학습시킨 모델의 결과보다 성능이 더 나아 이상치를 제거하지 않았음.

# %%
# 이상치 감지, 하지만 제거하지 않음
# train = train[train['avg_price_per_room'] < 340]
# train = train[train['lead_time'] < 400]

# %% [markdown]
# #### 2. feature 생성
# * no_of_total_nights: 숙박을 한 총 일 수
# * no_of_total_guests: 총 손님의 수
# * total_booking: 전체 에약 횟수
# * total_cost: 총 숙박비

# %%
for data in [train, test]:

    # no_of_total_nights = no_of_weekend_nights + no_of_week_nights
    data['no_of_total_nights'] = data['no_of_weekend_nights'] + data['no_of_week_nights']

    # no_of_total_guests = no_of_adults + no_of_children
    data['no_of_total_guests'] = data['no_of_adults'] + data['no_of_children']

    # total_bookings = no_of_previous_cancellations + no_of_previous_bookings_not_canceled
    data['total_bookings'] = data['no_of_previous_cancellations'] + data['no_of_previous_bookings_not_canceled']

    # total_cost = no_of_total_nights * avg_price_per_room
    data['total_cost'] = data['no_of_total_nights'] * data['avg_price_per_room']

# %% [markdown]
# 기존의 feature를 합쳐서 만든 새로운 feature가 기존의 feature를 합치기 전보다 booking_status과의 상관정도가 더 높을지 아닐지 판단하기 위해 이전 column은 삭제하지 않았음. 이후 target 값인 booking_status과의 상관계수 판단 후 선택적으로 삭제할 예정임.

# %%
# train 데이터 확인
train[num_cols].describe().T.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a037">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a037_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_7a037_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_7a037_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_7a037_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_7a037_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_7a037_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_7a037_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_7a037_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a037_level0_row0" class="row_heading level0 row0" >no_of_adults</th>
#       <td id="T_7a037_row0_col0" class="data row0 col0" >25392.000000</td>
#       <td id="T_7a037_row0_col1" class="data row0 col1" >1.845069</td>
#       <td id="T_7a037_row0_col2" class="data row0 col2" >0.519044</td>
#       <td id="T_7a037_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_7a037_row0_col4" class="data row0 col4" >2.000000</td>
#       <td id="T_7a037_row0_col5" class="data row0 col5" >2.000000</td>
#       <td id="T_7a037_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_7a037_row0_col7" class="data row0 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row1" class="row_heading level0 row1" >no_of_children</th>
#       <td id="T_7a037_row1_col0" class="data row1 col0" >25392.000000</td>
#       <td id="T_7a037_row1_col1" class="data row1 col1" >0.105151</td>
#       <td id="T_7a037_row1_col2" class="data row1 col2" >0.401900</td>
#       <td id="T_7a037_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_7a037_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_7a037_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_7a037_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_7a037_row1_col7" class="data row1 col7" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row2" class="row_heading level0 row2" >no_of_weekend_nights</th>
#       <td id="T_7a037_row2_col0" class="data row2 col0" >25392.000000</td>
#       <td id="T_7a037_row2_col1" class="data row2 col1" >0.810137</td>
#       <td id="T_7a037_row2_col2" class="data row2 col2" >0.867761</td>
#       <td id="T_7a037_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_7a037_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_7a037_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_7a037_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_7a037_row2_col7" class="data row2 col7" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row3" class="row_heading level0 row3" >no_of_week_nights</th>
#       <td id="T_7a037_row3_col0" class="data row3 col0" >25392.000000</td>
#       <td id="T_7a037_row3_col1" class="data row3 col1" >2.201323</td>
#       <td id="T_7a037_row3_col2" class="data row3 col2" >1.396599</td>
#       <td id="T_7a037_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_7a037_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_7a037_row3_col5" class="data row3 col5" >2.000000</td>
#       <td id="T_7a037_row3_col6" class="data row3 col6" >3.000000</td>
#       <td id="T_7a037_row3_col7" class="data row3 col7" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row4" class="row_heading level0 row4" >required_car_parking_space</th>
#       <td id="T_7a037_row4_col0" class="data row4 col0" >25392.000000</td>
#       <td id="T_7a037_row4_col1" class="data row4 col1" >0.031348</td>
#       <td id="T_7a037_row4_col2" class="data row4 col2" >0.174261</td>
#       <td id="T_7a037_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_7a037_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_7a037_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_7a037_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_7a037_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row5" class="row_heading level0 row5" >lead_time</th>
#       <td id="T_7a037_row5_col0" class="data row5 col0" >25392.000000</td>
#       <td id="T_7a037_row5_col1" class="data row5 col1" >85.411508</td>
#       <td id="T_7a037_row5_col2" class="data row5 col2" >85.745937</td>
#       <td id="T_7a037_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_7a037_row5_col4" class="data row5 col4" >17.000000</td>
#       <td id="T_7a037_row5_col5" class="data row5 col5" >58.000000</td>
#       <td id="T_7a037_row5_col6" class="data row5 col6" >127.000000</td>
#       <td id="T_7a037_row5_col7" class="data row5 col7" >443.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row6" class="row_heading level0 row6" >repeated_guest</th>
#       <td id="T_7a037_row6_col0" class="data row6 col0" >25392.000000</td>
#       <td id="T_7a037_row6_col1" class="data row6 col1" >0.025165</td>
#       <td id="T_7a037_row6_col2" class="data row6 col2" >0.156630</td>
#       <td id="T_7a037_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_7a037_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_7a037_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_7a037_row6_col6" class="data row6 col6" >0.000000</td>
#       <td id="T_7a037_row6_col7" class="data row6 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row7" class="row_heading level0 row7" >no_of_previous_cancellations</th>
#       <td id="T_7a037_row7_col0" class="data row7 col0" >25392.000000</td>
#       <td id="T_7a037_row7_col1" class="data row7 col1" >0.023905</td>
#       <td id="T_7a037_row7_col2" class="data row7 col2" >0.378652</td>
#       <td id="T_7a037_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_7a037_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_7a037_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_7a037_row7_col6" class="data row7 col6" >0.000000</td>
#       <td id="T_7a037_row7_col7" class="data row7 col7" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row8" class="row_heading level0 row8" >no_of_previous_bookings_not_canceled</th>
#       <td id="T_7a037_row8_col0" class="data row8 col0" >25392.000000</td>
#       <td id="T_7a037_row8_col1" class="data row8 col1" >0.156191</td>
#       <td id="T_7a037_row8_col2" class="data row8 col2" >1.818933</td>
#       <td id="T_7a037_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_7a037_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_7a037_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_7a037_row8_col6" class="data row8 col6" >0.000000</td>
#       <td id="T_7a037_row8_col7" class="data row8 col7" >58.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row9" class="row_heading level0 row9" >avg_price_per_room</th>
#       <td id="T_7a037_row9_col0" class="data row9 col0" >25392.000000</td>
#       <td id="T_7a037_row9_col1" class="data row9 col1" >103.485770</td>
#       <td id="T_7a037_row9_col2" class="data row9 col2" >35.067053</td>
#       <td id="T_7a037_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_7a037_row9_col4" class="data row9 col4" >80.750000</td>
#       <td id="T_7a037_row9_col5" class="data row9 col5" >99.865000</td>
#       <td id="T_7a037_row9_col6" class="data row9 col6" >120.150000</td>
#       <td id="T_7a037_row9_col7" class="data row9 col7" >375.500000</td>
#     </tr>
#     <tr>
#       <th id="T_7a037_level0_row10" class="row_heading level0 row10" >no_of_special_requests</th>
#       <td id="T_7a037_row10_col0" class="data row10 col0" >25392.000000</td>
#       <td id="T_7a037_row10_col1" class="data row10 col1" >0.618305</td>
#       <td id="T_7a037_row10_col2" class="data row10 col2" >0.786555</td>
#       <td id="T_7a037_row10_col3" clas

# %% [markdown]
# #### 3. 정규화

# %%
train.var()
# Out:
# no_of_adults                                0.269407
# no_of_children                              0.161524
# no_of_weekend_nights                        0.753010
# no_of_week_nights                           1.950488
# type_of_meal_plan                           0.514162
# required_car_parking_space                  0.030367
# room_type_reserved                          0.571573
# lead_time                                7352.365766
# arrival_year                                0.147944
# arrival_month                               9.361158
# arrival_date                               76.218207
# market_segment_type                         0.464285
# repeated_guest                              0.024533
# no_of_previous_cancellations                0.143377
# no_of_previous_bookings_not_canceled        3.308517
# avg_price_per_room                       1229.698231
# no_of_special_requests                      0.618668
# booking_status                              0.219736
# no_of_total_nights                          3.098408
# no_of_total_guests                          0.420506
# total_bookings                              4.112222
# total_cost                              46465.456329
# dtype: float64

# %% [markdown]
# 분산이 가장 높은 lead_time, avg_price_per_room, total_cost에 대해서 log scale로 변환

# %%
scale_col = ['lead_time', 'avg_price_per_room', 'total_cost']

for data in [train, test]:
    data['lead_time'] = np.log(data['lead_time'] + 1)
    data['avg_price_per_room'] = np.log(data['avg_price_per_room'] + 1)
    data['total_cost'] = np.log(data['total_cost'] + 1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25392 entries, 0 to 25391
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          25392 non-null  int64
#  1   no_of_children                        25392 non-null  int64
#  2   no_of_weekend_nights                  25392 non-null  int64
#  3   no_of_week_nights                     25392 non-null  int64
#  4   type_of_meal_plan                     25392 non-null  int64
#  5   required_car_parking_space            25392 non-null  int64
#  6   room_type_reserved                    25392 non-null  int64
#  7   lead_time                             25392 non-null  float64
#  8   arrival_year                          25392 non-null  int64
#  9   arrival_month                         25392 non-null  int64
#  10  arrival_date                          25392 non-null  int64
#  11  market_segment_type                   25392 non-null  int64
#  12  repeated_guest                        25392 non-null  int64
#  13  no_of_previous_cancellations          25392 non-null  int64
#  14  no_of_previous_bookings_not_canceled  25392 non-null  int64
#  15  avg_price_per_room                    25392 non-null  float64
#  16  no_of_special_requests                25392 non-null  int64
#  17  booking_status                        25392 non-null  int64
#  18  no_of_total_nights                    25392 non-null  int64
#  19  no_of_total_guests                    25392 non-null  int64
#  20  total_bookings                        25392 non-null  int64
#  21  total_cost                            25392 non-null  float64
# dtypes: float64(3), int64(19)
# memory usage: 4.3 MB

# %% [markdown]
# ## 3. feature 선택

# %%
sns.set(rc={'figure.figsize':(16, 14)}) 
correlation_matrix = train.corr()
sns.heatmap(data=correlation_matrix, annot=True) 
plt.show()

# %%
correlation = train.corr()['booking_status'].abs().sort_values(ascending = False)
correlation
# Out:
# booking_status                          1.000000
# lead_time                               0.376092
# no_of_special_requests                  0.254901
# arrival_year                            0.175495
# total_cost                              0.166556
# avg_price_per_room                      0.140024
# market_segment_type                     0.137250
# repeated_guest                          0.106916
# no_of_total_nights                      0.099812
# no_of_total_guests                      0.092777
# no_of_adults                            0.091378
# required_car_parking_space              0.090402
# no_of_week_nights                       0.090325
# no_of_previous_bookings_not_canceled    0.058706
# total_bookings                          0.058412
# no_of_weekend_nights                    0.057094
# type_of_meal_plan                       0.034755
# no_of_children                          0.031683
# no_of_previous_cancellations            0.030817
# arrival_month                           0.014238
# room_type_reserved                      0.013315
# arrival_date                            0.011965
# Name: booking_status, dtype: float64

# %%
feature_drop = [
    'arrival_date',
    'room_type_reserved', 
    'arrival_month',
    'no_of_previous_cancellations', 
    'no_of_children', 
    'type_of_meal_plan', 
    'no_of_weekend_nights', 
    'total_bookings', 
    'no_of_total_guests', 
]

train.drop(feature_drop, axis=1, inplace=True)
test.drop(feature_drop, axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25392 entries, 0 to 25391
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          25392 non-null  int64
#  1   no_of_week_nights                     25392 non-null  int64
#  2   required_car_parking_space            25392 non-null  int64
#  3   lead_time                             25392 non-null  float64
#  4   arrival_year                          25392 non-null  int64
#  5   market_segment_type                   25392 non-null  int64
#  6   repeated_guest                        25392 non-null  int64
#  7   no_of_previous_bookings_not_canceled  25392 non-null  int64
#  8   avg_price_per_room                    25392 non-null  float64
#  9   no_of_special_requests                25392 non-null  int64
#  10  booking_status                        25392 non-null  int64
#  11  no_of_total_nights                    25392 non-null  int64
#  12  total_cost                            25392 non-null  float64
# dtypes: float64(3), int64(10)
# memory usage: 2.5 MB

# %%
train.head()
# Out:
#    no_of_adults  no_of_week_nights  required_car_parking_space  lead_time  \
# 0             2                  3                           0   5.303305
# 1             2                  3                           0   4.382027
# 2             2                  4                           0   4.369448
# 3             2                  0                           0   4.127134
# 4             2                  4                           0   5.308268
#
#    arrival_year  market_segment_type  repeated_guest  \
# 0          2018                    0               0
# 1          2018                    0               0
# 2          2018                    0               0
# 3          2017                    1               0
# 4          2018                    0               0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0            4.521245
# 1                                     0            4.521245
# 2                                     0            4.609660
# 3                                     0            4.521789
# 4                                     0            4.422208
#
#    no_of_special_requests  booking_status  no_of_total_nights  total_cost
# 0                       0               1                   4    5.899349
# 1                       1               1                   4    5.899349
# 2                       1               0                   5    6.211102
# 3                       0               0                   2    5.209486
# 4                       3               0                   4    5.799456

# %%
test.head()
# Out:
#    no_of_adults  no_of_week_nights  required_car_parking_space  lead_time  \
# 0             2                  0                           0   1.386294
# 1             2                  2                           0   2.302585
# 2             2                  2                           0   3.218876
# 3             2                  3                           0   3.178054
# 4             2                  2                           0   2.302585
#
#    arrival_year  market_segment_type  repeated_guest  \
# 0          2017                    0               0
# 1          2018                    1               0
# 2          2018                    0               0
# 3          2018                    0               0
# 4          2018                    0               0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0            4.510860
# 1                                     0            3.905401
# 2                                     0            4.566429
# 3                                     0            4.857251
# 4                                     0            5.310740
#
#    no_of_special_requests  no_of_total_nights  total_cost
# 0                       3                   1    4.510860
# 1                       0                   3    4.990501
# 2                       1                   4    5.944897
# 3                       0                   3    5.950669
# 4                       2                   2    6.001415

# %% [markdown]
# ## 4. model 선택

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
target = train['booking_status']
train.drop(['booking_status'], axis=1, inplace=True)

accuracy = []

# %% [markdown]
# ### 1. Decision Tree

# %%
clf_tree = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=17,
    min_samples_split=2,
    min_samples_leaf=2,
    max_features=4,
    # random_state=1
)
scoring = 'accuracy'
score = cross_val_score(clf_tree, train, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.87086614 0.84724409 0.87908625 0.85427334 0.85151635 0.87948011
#  0.86136274 0.86451359 0.86608901 0.85860575]

# %%
# Decision Tree Score
accuracy.append(round(np.mean(score) * 100, 3))
# round(np.mean(score) * 100, 3)
accuracy[0]
# Out:
# 86.33

# %% [markdown]
# ### 2. k-Nearest Neighbors

# %%
knn = KNeighborsClassifier(
    n_neighbors=37,
    # leaf_size=10,
    weights='distance',
    p=1,
    metric='manhattan'
)
scoring = 'accuracy'
score = cross_val_score(knn, train, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.87165354 0.86771654 0.87199685 0.87593541 0.87711698 0.88302481
#  0.87160299 0.87120914 0.87672312 0.86490744]

# %%
# k-Nearest Neighbors Score
accuracy.append(round(np.mean(score) * 100, 3))
accuracy[1]
# Out:
# 87.319

# %% [markdown]
# ### 3. Naïve Bayes

# %%
nb_model = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(nb_model, train, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.4480315  0.45748031 0.45844821 0.45844821 0.46908232 0.45923592
#  0.47183931 0.45569122 0.45844821 0.46396219]

# %%
# Naïve Bayes Score
accuracy.append(round(np.mean(score) * 100, 3))
accuracy[2]
# Out:
# 46.007

# %% [markdown]
# ### 4. Logistic Regression

# %%
lr_model = LogisticRegression()
scoring = 'accuracy'
score = cross_val_score(lr_model, train, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0.78897638 0.78149606 0.8011028  0.78298543 0.79401339 0.80228436
#  0.78062229 0.78101615 0.79519496 0.78968098]
# /Users/min02choi/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Logistic regression Score
accuracy.append(round(np.mean(score) * 100, 3))
accuracy[3]
# Out:
# 78.974

# %% [markdown]
# ### 5. Artificial Neural Networks

# %%
mlp_model = MLPClassifier()
score = cross_val_score(mlp_model, train, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.59291339 0.53582677 0.78456085 0.61795983 0.79519496 0.66601024
#  0.73808586 0.73651044 0.68058291 0.76920047]

# %%
# Artificial Neural Score
accuracy.append(round(np.mean(score) * 100, 3))
accuracy[4]
# Out:
# 69.168

# %%
print('DecisionTreeClassifier 정확도:', accuracy[0])
print('NearestNeighbors 정확도:', accuracy[1])
print('GaussianNB 정확도:', accuracy[2])
print('LogisticRegression 정확도:', accuracy[3])
print('MLPClassifier 정확도:', accuracy[4])
# Out:
# DecisionTreeClassifier 정확도: 86.33
# NearestNeighbors 정확도: 87.319
# GaussianNB 정확도: 46.007
# LogisticRegression 정확도: 78.974
# MLPClassifier 정확도: 69.168

# %% [markdown]
# k-fold를 10번하여 정확도의 평균을 낸 결과가 가장 높은 NearestNeighbors 모델을 선택함

# %% [markdown]
# ## 5. 성능 평가 및 제출

# %%
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.2)
knn.fit(X_train,y_train)
knn_pred = knn.predict(X_test)
accuracy_score(y_test, knn_pred)
# Out:
# 0.8783225044300059

# %%
# knn.fit(train, target)
prediction_list = knn.predict(test)

submit = pd.read_csv("./sample_submission.csv")
submit["booking_status"] = prediction_list
submit = submit.replace({'Canceled':1, 'Not_Canceled':0})
submit
# Out:
#       Booking_ID  booking_status
# 0       INN04969               0
# 1       INN34541               0
# 2       INN36109               0
# 3       INN01554               1
# 4       INN24975               0
# ...          ...             ...
# 10878   INN29686               0
# 10879   INN01107               1
# 10880   INN06811               0
# 10881   INN27777               1
# 10882   INN04027               1
#
# [10883 rows x 2 columns]

# %%
submit.to_csv("dt_submit.csv",index=False)
